# %%
hangman=["~~~~~~~~~~~","~~~~~~~~~~~~\n|\n|\n|\n|\n|\n|\n|\n|\n",
        "~~~~~~~~~~~~\n|\n|\n|\n|\n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|\n|\n|\n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|\n|\n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|         O\n|\n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|         O\n|         |\\ \n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|         O\n|        /|\\ \n|\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|         O\n|        /|\\ \n|         |\n|\n|\n|______________",
        "~~~~~~~~~~~~\n|         |\n|         |\n|         O\n|        /|\\ \n|         |\n|        / \\ \n|\n|\n|______________"]

# %%
import random

word_list=['earthquake', 'structural', 'presenter', 'asking', 'producers', 'Several', 'towers', 'hospital',
 'briefly', 'evacuated,', 'residents', 'suspended', 'australia', 'premier', 'federal','ground', 'shaking',
 'violently', 'Wagga,', 'earthquakes', 'uncommon',  'because', 'continent', 'centrally', 'tectonic',
 'struck', 'shallow', 'according', 'Geosciences', 'initially', 'measured', 'magnitude', 'before', 'revised',
'geoscience', 'agency',  'experiences', 'potentially', 'damaging', 'earthquake', 'defined', 'magnitude',
 'melbourne,', 'second', 'largest', 'million', 'currently', 'lockdown', 'recent', 'coronavirus']

word = random.choice(word_list)

# %%
length = len(word)
user_list = ['_']*length

# %%
counter =0
status = False
false_count = 0
while '_' in user_list:
    print("count :\t",counter)
    if false_count<10:
        guess = input("guess your character: \t")
        counter += 1
        for i in range(len(word)):
            
            if guess == word[i]:
                status = True
                user_list[i] = guess
                break
            else:
                pass
            status = False

        print("status :",status)
        if status == True:
            if user_list == list(word):
                print("you win")
        elif status ==False:
            false_count+=1
            print(false_count)
            print(hangman[false_count-1])
        print(user_list)        
    else:
        print("you loose, hangman is dead")
        break
# Out:
# count :	 0
# guess your character: 	z
# status : False
# 1
# ~~~~~~~~~~~
# ['_', '_', '_', '_', '_', '_']
# count :	 1
# guess your character: 	z
# status : False
# 2
# ~~~~~~~~~~~~
# |
# |
# |
# |
# |
# |
# |
# |
#
# ['_', '_', '_', '_', '_', '_']
# count :	 2
# guess your character: 	z
# status : False
# 3
# ~~~~~~~~~~~~
# |
# |
# |
# |
# |
# |
# |
# |______________
# ['_', '_', '_', '_', '_', '_']
# count :	 3
# guess your character: 	z
# status : False
# 4
# ~~~~~~~~~~~~
# |         |
# |
# |
# |
# |
# |
# |
# |______________
# ['_', '_', '_', '_', '_', '_']
# count :	 4
# guess your character: 	z
# status : False
# 5
# ~~~~~~~~~~~~
# |         |
# |         |
# |
# |
# |
# |
# |
# |______________
# ['_', '_', '_', '_', '_', '_']
# count :	 5
# guess your character: 	z
# status : False
# 6
# ~~~~~~~~~~~~
# |         |
# |         |
# |         O
# |
# |
# |
# |
# |______________
# ['_', '_', '_', '_', '_', '_']
# count :	 6
# guess your character: 	z
# status : False
# 7
# ...
