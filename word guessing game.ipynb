# %% [markdown]
# #### word guessing game

# %%
word_list='''Is it an earthquake or a structural thing?" presenter Michael Rowland was later shown asking 
producersLets go… that was a big one.
Several high-rise towers and a city hospital were also briefly evacuated, residents reported. Some city
tram lines had been suspended due to damage.
South Australia Premier Stephen Marshall said his state had felt aftershocks.
One federal MP, Michael McCormack, said the "ground [was] shaking violently in Wagga Wagga, NSW.
Large earthquakes are uncommon in Australia because the continent lies centrally on a tectonic plate.
This quake struck at a shallow depth of 10km (6.5 miles), according to Geosciences Australia. It was initially
measured at 6.0 magnitude before being revised to 5.9.
The geoscience agency says Australia experiences a potentially damaging earthquake - defined as above 6.0 
magnitude - about every 10 years.
Melbourne, the country's second largest city, is home to about five million people.
The city is currently in lockdown due to a recent wave of coronavirus cases.'''

# %%
word_list.split()
# Out:
# ['Is',
#  'it',
#  'an',
#  'earthquake',
#  'or',
#  'a',
#  'structural',
#  'thing?"',
#  'presenter',
#  'Michael',
#  'Rowland',
#  'was',
#  'later',
#  'shown',
#  'asking',
#  'producersLets',
#  'go…',
#  'that',
#  'was',
#  'a',
#  'big',
#  'one.',
#  'Several',
#  'high-rise',
#  'towers',
#  'and',
#  'a',
#  'city',
#  'hospital',
#  'were',
#  'also',
#  'briefly',
#  'evacuated,',
#  'residents',
#  'reported.',
#  'Some',
#  'city',
#  'tram',
#  'lines',
#  'had',
#  'been',
#  'suspended',
#  'due',
#  'to',
#  'damage.',
#  'South',
#  'Australia',
#  'Premier',
#  'Stephen',
#  'Marshall',
#  'said',
#  'his',
#  'state',
#  'had',
#  'felt',
#  'aftershocks.',
#  'One',
#  'federal',
#  'MP,',
#  'Michael',
#  'McCormack,',
#  'said',
#  'the',
#  '"ground',
#  '[was]',
#  'shaking',
#  'violently',
#  'in',
#  'Wagga',
#  'Wagga,',
#  'NSW.',
#  'Large',
#  'earthquakes',
#  'are',
#  'uncommon',
#  'in',
#  'Australia',
#  'because',
#  'the',
# ...

# %%
word_list1=[]
for word in word_list.split():
    if '?' in word or '.' in word or ')' in word or '[' in word or "'" in word or '-' in word:
        pass
    
    elif len(word)>5:
        word_list1.append(word)
word_list1
# Out:
# ['earthquake',
#  'structural',
#  'presenter',
#  'Michael',
#  'Rowland',
#  'asking',
#  'producersLets',
#  'Several',
#  'towers',
#  'hospital',
#  'briefly',
#  'evacuated,',
#  'residents',
#  'suspended',
#  'Australia',
#  'Premier',
#  'Stephen',
#  'Marshall',
#  'federal',
#  'Michael',
#  'McCormack,',
#  '"ground',
#  'shaking',
#  'violently',
#  'Wagga,',
#  'earthquakes',
#  'uncommon',
#  'Australia',
#  'because',
#  'continent',
#  'centrally',
#  'tectonic',
#  'struck',
#  'shallow',
#  'according',
#  'Geosciences',
#  'initially',
#  'measured',
#  'magnitude',
#  'before',
#  'revised',
#  'geoscience',
#  'agency',
#  'Australia',
#  'experiences',
#  'potentially',
#  'damaging',
#  'earthquake',
#  'defined',
#  'magnitude',
#  'Melbourne,',
#  'second',
#  'largest',
#  'million',
#  'currently',
#  'lockdown',
#  'recent',
#  'coronavirus']

# %%
# multiple instances of 'australia' and names of people deleted manually to get below list

word_list=['earthquake', 'structural', 'presenter', 'asking', 'producers', 'Several', 'towers', 'hospital',
 'briefly', 'evacuated,', 'residents', 'suspended', 'australia', 'Premier', 'federal','ground', 'shaking',
 'violently', 'Wagga,', 'earthquakes', 'uncommon',  'because', 'continent', 'centrally', 'tectonic',
 'struck', 'shallow', 'according', 'Geosciences', 'initially', 'measured', 'magnitude', 'before', 'revised',
'geoscience', 'agency',  'experiences', 'potentially', 'damaging', 'earthquake', 'defined', 'magnitude',
 'melbourne,', 'second', 'largest', 'million', 'currently', 'lockdown', 'recent', 'coronavirus']

# %%
word_to_guess = random.choice(word_list)

#print(word_to_guess)----------- use this only to debug if there is any problem

#print("length :",len (word_to_guess))----------- use this only to debug if there is any problem

no_of_chances = round(len(word_to_guess)+len(word_to_guess)/2)

#print("chances :",no_of_chances)----------- use this only to debug if there is any problem

# %%
list1 = ['_']*len (word_to_guess)

print(list1)

count = 0
while count < no_of_chances:
    count += 1
    guess = input("\nguess a char from a to z :\t")


    for i in range(len(word_to_guess)):
        if guess == word_to_guess[i]:
            list1[i] = guess
            print(list1)
        else:
            pass
    if ''.join(list1) == word_to_guess:
        print(f"\nyou got it in {count} moves")
        break

if '_' in list1:
    print("better luck next time")
else:
    print(list1)

print(f"\nword was :\t {word_to_guess}")
# Out:
# ['_', '_', '_', '_', '_', '_', '_']
#
# guess a char from a to z :	b
# ['b', '_', '_', '_', '_', '_', '_']
#
# guess a char from a to z :	e
# ['b', 'e', '_', '_', '_', '_', '_']
# ['b', 'e', '_', '_', '_', '_', 'e']
#
# guess a char from a to z :	c
# ['b', 'e', 'c', '_', '_', '_', 'e']
#
# guess a char from a to z :	a
# ['b', 'e', 'c', 'a', '_', '_', 'e']
#
# guess a char from a to z :	u
# ['b', 'e', 'c', 'a', 'u', '_', 'e']
#
# guess a char from a to z :	s
# ['b', 'e', 'c', 'a', 'u', 's', 'e']
#
# you got it in 6 moves
# ['b', 'e', 'c', 'a', 'u', 's', 'e']
#
# word was :	 because
